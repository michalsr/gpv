# %%
import os

# %%
print(os.listdir('/data/michal5/gpv/learning_phase_data'))
# Out:
# ['.hydra', '__MACOSX', 'web_20', 'web_full_info.zip', 'coco_captions', 'refcocop.zip', 'vocab', 'web_20_temp', 'download.log', 'refcocop', 'web_80.zip', 'split_coco_categories', 'coco_classification', 'vqa', 'coco_original_and_sce_splits.zip', 'val_image_info.json', 'train_image_info.json', 'held_out_json', 'held_out_json.zip', 'split_coco_images', 'test_image_info.json', 'coco_detection', 'coco']

# %%
img = os.listdir('/data/michal5/web_data/')

# %%
from IPython.core.display import display, HTML

# %%
from IPython.display import HTML

# %%
print(os.listdir('/data/michal5/web_data/'))
# Out:
# ['5b41bd9c1c98e2096900d5f78913ba3fcac43f0b0c546fcf9259bf15a517cea6.html', '4b0501b08a26d266d4259003472069f2373872044f2a1fba22a06892cc3f3a45.html', '069c4f84b6dc22d5b10517b17ac6e4bc5e95b827f56240099549cd9df129495f.html', '000ebc30a9473f3e2aa4d3e046807bf8ce53dea77f04901e8412a516b8326852.html', '14f8c4ffc541b4e891a1310c061c7bb02be3e9750c5f9db1dbd71dbdabfd2be5.html', '14ea77ddc4db911cb7d2536c7bd2fc9a0a664d5980f278ccce0d2459abd81fe6.html', '46385a79186dc0345d799362db6e6c6aeba114184f9204574805ca1ee344b464.html', '022f1713b6d29577baab65667911a20e9e9452bd014d0c900e7cdcb5b3cf9114.html', '3d6e4f54367f41eb7acd28dac0c2cc3136d6786d12a9ab2deaa4dda4b2d11c88.html', '52748d8a26955184e2f6a253e01d59df2c007ceacf82e9f9d8abc1ae5552e2ab.html', '03dfcbe54d84717f5a2c72ad655a6e24d07b811447248d9dd5d5a6e769ae81c2.html', '5706934f84df98ae5e8467d8a11453a2663e3040e654c4e4f780da29fc00772f.html', '480c985286ee6c7ef73e061cec245aa41ba27f79b93dfe66216a996afc0b9d9e.html', '477e00ccb151d32aec28fb3d96961078ee1da9cbfd83c61
# ...

# %%
HTML(filename='/data/michal5/web_data/5b41bd9c1c98e2096900d5f78913ba3fcac43f0b0c546fcf9259bf15a517cea6.html')
# Out:
# <html>
# <head>
# <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css" integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm" crossorigin="anonymous">
# </head>
# <body>
# <h4>in labor</h4>
# <table class="table">
#   <thead>
#     <tr>
#       <th scope="col">Image</th>
#     </tr>
#   </thead>
#   <tbody>
#
#     <tr>
#     <td align="center"><img src="https://tse4.mm.bing.net/th?id=OIP.1zU55MLWLNkE2v2L56ocowHaFe&pid=Api" width="300"/></td>
#     </tr>
#
#     <tr>
#     <td align="center"><img src="https://tse4.mm.bing.net/th?id=OIP.On2t4emfhtxe58UJLAZc0gHaE6&pid=Api" width="300"/></td>
#     </tr>
#
#     <tr>
#     <td align="center"><img src="https://tse1.mm.bing.net/th?id=OIP.-T9BVNT76Dv8bySjIYCJlAHaEK&pid=Api" width="300"/></td>
#     </tr>
#
#     <tr>
#     <td align="center"><img src="https://tse2.mm.bing.net/th?id=OIP.PmX49Xuep4indG_K9u0m5AAAAA&pid=Api" width="300"/></td>
#     </tr>
#
#     <tr>
# ...

# %%
# !pip install python-magic

# %%
import magic

# %%
magic.from_file('/data/michal5/web_data/images/ffffdba4cdd6dd7740d9180b25524c539d556f150e4f1692a274e047fe3a9113/')
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-11-9cfe62e4ee58> in <module>
# ----> 1 magic.from_file('/data/michal5/web_data/images/ffffdba4cdd6dd7740d9180b25524c539d556f150e4f1692a274e047fe3a9113/')
#
# ~/anaconda3/lib/python3.8/site-packages/magic/__init__.py in from_file(filename, mime)
#     176     """
#     177     m = _get_magic_type(mime)
# --> 178     return m.from_file(filename)
#     179
#     180
#
# ~/anaconda3/lib/python3.8/site-packages/magic/__init__.py in from_file(self, filename)
#     109     def from_file(self, filename):
#     110         # raise FileNotFoundException or IOError if the file does not exist
# --> 111         with _real_open(filename):
#     112             pass
#     113
#
# NotADirectoryError: [Errno 20] Not a directory: '/data/michal5/web_data/images/ffffdba4cdd6dd7740d9180b25524c539d556f150e4f1692a274e047fe3a9113/'
